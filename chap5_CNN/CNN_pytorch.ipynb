# %%
import os
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.utils.data as Data
import torchvision
import torch.nn.functional as F
import numpy as np
learning_rate = 1e-4
keep_prob_rate = 0.7 #
max_epoch = 3
BATCH_SIZE = 50

DOWNLOAD_MNIST = False
if not(os.path.exists('./mnist/')) or not os.listdir('./mnist/'):
    # not mnist dir or mnist is empyt dir
    DOWNLOAD_MNIST = True


train_data = torchvision.datasets.MNIST(root='./mnist/',train=True, transform=torchvision.transforms.ToTensor(), download=DOWNLOAD_MNIST,)
train_loader = Data.DataLoader(dataset=train_data ,batch_size= BATCH_SIZE ,shuffle=True)

test_data = torchvision.datasets.MNIST(root = './mnist/',train = False)
test_x = Variable(torch.unsqueeze(test_data.test_data,dim=1),volatile=True).type(torch.FloatTensor)[:500]/255.  # shape from (2000,28,28) to (2000,1,28,28), value in range(0,1)
test_y = test_data.test_labels[:500].numpy()

class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d( # ???
                # patch 7 * 7 ; 1  in channels ; 32 out channels ; ; stride is 1
                # padding style is same(that means the convolution opration's input and output have the same size)
                in_channels=1,
                out_channels=32,
                kernel_size=3,
                stride=1,
                padding=1,
            ),
            nn.ReLU(),        # activation function
            nn.MaxPool2d(2),  # pooling operation
        )
        self.conv2 = nn.Sequential( # ???
            # line 1 : convolution function, patch 5*5 , 32 in channels ;64 out channels; padding style is same; stride is 1
            # line 2 : choosing your activation funciont
            # line 3 : pooling operation function.
            nn.Conv2d(
                in_channels=32,
                out_channels=64,
                kernel_size=3,
                stride=1,
                padding=1,
            ),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        self.out1 = nn.Linear(7*7*64 , 1024 , bias= True)   # full connection layer one

        self.dropout = nn.Dropout(keep_prob_rate)
        self.out2 = nn.Linear(1024,10,bias=True)



    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = x.view((-1, 3136))  # flatten the output of coonv2 to (batch_size ,32 * 7 * 7)    # ???
        out1 = self.out1(x)
        out1 = F.relu(out1)
        out1 = self.dropout(out1)
        out2 = self.out2(out1)
        output = F.softmax(out2)
        return output


def test(cnn):
    global prediction
    y_pre = cnn(test_x)
    _,pre_index= torch.max(y_pre,1)
    pre_index= pre_index.view(-1)
    prediction = pre_index.data.numpy()
    correct  = np.sum(prediction == test_y)
    return correct / 500.0


def train(cnn):
    optimizer = torch.optim.Adam(cnn.parameters(), lr=learning_rate )
    loss_func = nn.CrossEntropyLoss()
    for epoch in range(max_epoch):
        for step, (x_, y_) in enumerate(train_loader):
            x ,y= Variable(x_),Variable(y_)
            output = cnn(x)  
            loss = loss_func(output,y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            if step != 0 and step % 20 ==0:
                print("=" * 10,step,"="*5,"="*5, "test accuracy is ",test(cnn) ,"=" * 10 )

if __name__ == '__main__':
    cnn = CNN()
    train(cnn)
# Out:
# d:\86188\Software_Tool\Miniconda\envs\nndl\lib\site-packages\ipykernel_launcher.py:24: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# d:\86188\Software_Tool\Miniconda\envs\nndl\lib\site-packages\ipykernel_launcher.py:72: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# ========== 20 ===== ===== test accuracy is  0.316 ==========
# ========== 40 ===== ===== test accuracy is  0.372 ==========
# ========== 60 ===== ===== test accuracy is  0.364 ==========
# ========== 80 ===== ===== test accuracy is  0.504 ==========
# ========== 100 ===== ===== test accuracy is  0.59 ==========
# ========== 120 ===== ===== test accuracy is  0.608 ==========
# ========== 140 ===== ===== test accuracy is  0.638 ==========
# ========== 160 ===== ===== test accuracy is  0.734 ==========
# ========== 180 ===== ===== test accuracy is  0.718 ==========
# ========== 200 ===== ===== test accuracy is  0.75 ==========
# ========== 220 ===== ===== test accuracy is  0.798 ==========
# ========== 240 ===== ===== test accuracy is  0.796 ==========
# ========== 260 ===== ===== test accuracy is  0.804 ==========
# ========== 280 ===== ===== test accuracy is  0.804 ==========
# ========== 300 ===== ===== test accuracy is  0.84 ==========
# ========== 320 ===== ===== test accuracy is  0.85 ==========
# ========== 340 ===== ===== test accuracy is  0.844 ==========
# ========== 360 ===== ===== test accuracy is  0.894 ==========
# ========== 380 ===== ===== test accuracy is  0.874 ==========
# ========== 400 ===== ===== test accuracy is  0.858 ==========
# ========== 420 ===== ===== test accuracy is  0.872 ==========
# ========== 440 ===== ===== test accuracy is  0.872 ==========
# ========== 460 ===== ===== test accuracy is  0.9 ==========
# ========== 480 ===== ===== test accuracy is  0.884 ==========
# ========== 500 ===== ===== test accuracy is  0.896 ==========
# ========== 520 ===== ===== test accuracy is  0.908 ==========
# ========== 540 ===== ===== test accuracy is  0.902 ==========
# ========== 560 ===== ===== test accuracy is  0.904 ==========
# ========== 580 ===== ===== test accuracy is  0.906 ==========
# ========== 600 ===== ===== test accuracy is  0.904 ==========
# ========== 620 ===== ===== test accuracy is  0.908 ==========
# ========== 640 ===== ===== test accuracy is  0.904 ==========
# ========== 660 ===== ===== test accuracy is  0.898 ==========
# ========== 680 ===== ===== test accuracy is  0.922 ==========
# ========== 700 ===== ===== test accuracy is  0.91 ==========
# ========== 720 ===== ===== test accuracy is  0.916 ==========
# ========== 740 ===== ===== test accuracy is  0.9 ==========
# ========== 760 ===== ===== test accuracy is  0.908 ==========
# ========== 780 ===== ===== test accuracy is  0.926 ==========
# ========== 800 ===== ===== test accuracy is  0.918 ==========
# ========== 820 ===== ===== test accuracy is  0.92 ==========
# ========== 840 ===== ===== test accuracy is  0.928 ==========
# ========== 860 ===== ===== test accuracy is  0.934 ==========
# ========== 880 ===== ===== test accuracy is  0.926 ==========
# ========== 900 ===== ===== test accuracy is  0.932 ==========
# ========== 920 ===== ===== test accuracy is  0.924 ==========
# ========== 940 ===== ===== test accuracy is  0.934 ==========
# ========== 960 ===== ===== test accuracy is  0.93 ==========
# ========== 980 ===== ===== test accuracy is  0.922 ==========
# ========== 1000 ===== ===== test accuracy is  0.928 ==========
# ========== 1020 ===== ===== test accuracy is  0.926 ==========
# ========== 1040 ===== ===== test accuracy is  0.928 ==========
# ========== 1060 ===== ===== test accuracy is  0.936 ==========
# ========== 1080 ===== ===== test accuracy is  0.932 ==========
# ========== 1100 ===== ===== test accuracy is  0.932 ==========
# ========== 1120 ===== ===== test accuracy is  0.936 ==========
# ========== 1140 ===== ===== test accuracy is  0.938 ==========
# ========== 1160 ===== ===== test accuracy is  0.934 ==========
# ========== 1180 ===== ===== test accuracy is  0.94 ==========
# ========== 20 ===== ===== test accuracy is  0.942 ==========
# ========== 40 ===== ===== test accuracy is  0.938 ==========
# ========== 60 ===== ===== test accuracy is  0.934 ==========
# ========== 80 ===== ===== test accuracy is  0.936 ==========
# ========== 100 ===== ===== test accuracy is  0.932 ==========
# ========== 120 ===== ===== test accuracy is  0.934 ==========
# ========== 140 ===== ===== test accuracy is  0.934 ==========
# ========== 160 ===== ===== test accuracy is  0.944 ==========
# ========== 180 ===== ===== test accuracy is  0.944 ==========
# ========== 200 ===== ===== test accuracy is  0.928 ==========
# ========== 220 ===== ===== test accuracy is  0.95 ==========
# ========== 240 ===== ===== test accuracy is  0.948 ==========
# ========== 260 ===== ===== test accuracy is  0.936 ==========
# ========== 280 ===== ===== test accuracy is  0.944 ==========
# ========== 300 ===== ===== test accuracy is  0.958 ==========
# ========== 320 ===== ===== test accuracy is  0.944 ==========
# ========== 340 ===== ===== test accuracy is  0.944 ==========
# ========== 360 ===== ===== test accuracy is  0.95 ==========
# ========== 380 ===== ===== test accuracy is  0.954 ==========
# ========== 400 ===== ===== test accuracy is  0.948 ==========
# ========== 420 ===== ===== test accuracy is  0.95 ==========
# ========== 440 ===== ===== test accuracy is  0.946 ==========
# ========== 460 ===== ===== test accuracy is  0.954 ==========
# ========== 480 ===== ===== test accuracy is  0.95 ==========
# ========== 500 ===== ===== test accuracy is  0.95 ==========
# ========== 520 ===== ===== test accuracy is  0.95 ==========
# ========== 540 ===== ===== test accuracy is  0.954 ==========
# ========== 560 ===== ===== test accuracy is  0.954 ==========
# ========== 580 ===== ===== test accuracy is  0.954 ==========
# ========== 600 ===== ===== test accuracy is  0.946 ==========
# ========== 620 ===== ===== test accuracy is  0.94 ==========
# ========== 640 ===== ===== test accuracy is  0.948 ==========
# ========== 660 ===== ===== test accuracy is  0.954 ==========
# ========== 680 ===== ===== test accuracy is  0.958 ==========
# ========== 700 ===== ===== test accuracy is  0.956 ==========
# ========== 720 ===== ===== test accuracy is  0.956 ==========
# ========== 740 ===== ===== test accuracy is  0.964 ==========
# ========== 760 ===== ===== test accuracy is  0.956 ==========
# ========== 780 ===== ===== test accuracy is  0.952 ==========
# ========== 800 ===== ===== test accuracy is  0.962 ==========
# ========== 820 ===== ===== test accuracy is  0.95 ==========
# ========== 840 ===== ===== test accuracy is  0.958 ==========
# ========== 860 ===== ===== test accuracy is  0.952 ==========
# ========== 880 ===== ===== test accuracy is  0.96 ==========
# ========== 900 ===== ===== test accuracy is  0.956 ==========
# ========== 920 ===== ===== test accuracy is  0.956 ==========
# ========== 940 ===== ===== test accuracy is  0.954 ==========
# ========== 960 ===== ===== test accuracy is  0.956 ==========
# ========== 980 ===== ===== test accuracy is  0.956 ==========
# ========== 1000 ===== ===== test accuracy is  0.964 ==========
# ========== 1020 ===== ===== test accuracy is  0.948 ==========
# ========== 1040 ===== ===== test accuracy is  0.962 ==========
# ========== 1060 ===== ===== test accuracy is  0.95 ==========
# ========== 1080 ===== ===== test accuracy is  0.96 ==========
# ========== 1100 ===== ===== test accuracy is  0.96 ==========
# ========== 1120 ===== ===== test accuracy is  0.956 ==========
# ========== 1140 ===== ===== test accuracy is  0.95 ==========
# ========== 1160 ===== ===== test accuracy is  0.954 ==========
# ========== 1180 ===== ===== test accuracy is  0.962 ==========
# ========== 20 ===== ===== test accuracy is  0.968 ==========
# ========== 40 ===== ===== test accuracy is  0.966 ==========
# ========== 60 ===== ===== test accuracy is  0.956 ==========
# ========== 80 ===== ===== test accuracy is  0.962 ==========
# ========== 100 ===== ===== test accuracy is  0.956 ==========
# ========== 120 ===== ===== test accuracy is  0.962 ==========
# ========== 140 ===== ===== test accuracy is  0.964 ==========
# ========== 160 ===== ===== test accuracy is  0.956 ==========
# ========== 180 ===== ===== test accuracy is  0.958 ==========
# ========== 200 ===== ===== test accuracy is  0.962 ==========
# ========== 220 ===== ===== test accuracy is  0.962 ==========
# ========== 240 ===== ===== test accuracy is  0.962 ==========
# ========== 260 ===== ===== test accuracy is  0.964 ==========
# ========== 280 ===== ===== test accuracy is  0.958 ==========
# ========== 300 ===== ===== test accuracy is  0.96 ==========
# ========== 320 ===== ===== test accuracy is  0.966 ==========
# ========== 340 ===== ===== test accuracy is  0.96 ==========
# ========== 360 ===== ===== test accuracy is  0.962 ==========
# ========== 380 ===== ===== test accuracy is  0.966 ==========
# ========== 400 ===== ===== test accuracy is  0.968 ==========
# ========== 420 ===== ===== test accuracy is  0.956 ==========
# ========== 440 ===== ===== test accuracy is  0.968 ==========
# ========== 460 ===== ===== test accuracy is  0.962 ==========
# ========== 480 ===== ===== test accuracy is  0.962 ==========
# ========== 500 ===== ===== test accuracy is  0.966 ==========
# ========== 520 ===== ===== test accuracy is  0.968 ==========
# ========== 540 ===== ===== test accuracy is  0.97 ==========
# ========== 560 ===== ===== test accuracy is  0.966 ==========
# ========== 580 ===== ===== test accuracy is  0.96 ==========
# ========== 600 ===== ===== test accuracy is  0.97 ==========
# ========== 620 ===== ===== test accuracy is  0.962 ==========
# ========== 640 ===== ===== test accuracy is  0.96 ==========
# ========== 660 ===== ===== test accuracy is  0.964 ==========
# ========== 680 ===== ===== test accuracy is  0.972 ==========
# ========== 700 ===== ===== test accuracy is  0.958 ==========
# ========== 720 ===== ===== test accuracy is  0.972 ==========
# ========== 740 ===== ===== test accuracy is  0.962 ==========
# ========== 760 ===== ===== test accuracy is  0.966 ==========
# ========== 780 ===== ===== test accuracy is  0.96 ==========
# ========== 800 ===== ===== test accuracy is  0.958 ==========
# ========== 820 ===== ===== test accuracy is  0.966 ==========
# ========== 840 ===== ===== test accuracy is  0.968 ==========
# ========== 860 ===== ===== test accuracy is  0.966 ==========
# ========== 880 ===== ===== test accuracy is  0.964 ==========
# ========== 900 ===== ===== test accuracy is  0.976 ==========
# ========== 920 ===== ===== test accuracy is  0.958 ==========
# ========== 940 ===== ===== test accuracy is  0.968 ==========
# ========== 960 ===== ===== test accuracy is  0.966 ==========
# ========== 980 ===== ===== test accuracy is  0.97 ==========
# ========== 1000 ===== ===== test accuracy is  0.97 ==========
# ========== 1020 ===== ===== test accuracy is  0.966 ==========
# ========== 1040 ===== ===== test accuracy is  0.966 ==========
# ========== 1060 ===== ===== test accuracy is  0.964 ==========
# ========== 1080 ===== ===== test accuracy is  0.972 ==========
# ========== 1100 ===== ===== test accuracy is  0.966 ==========
# ========== 1120 ===== ===== test accuracy is  0.974 ==========
# ========== 1140 ===== ===== test accuracy is  0.97 ==========
# ========== 1160 ===== ===== test accuracy is  0.968 ==========
# ========== 1180 ===== ===== test accuracy is  0.974 ==========
